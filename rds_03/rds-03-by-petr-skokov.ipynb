# %% [markdown]
# # Прогнозирование стоимости автомобиля по характеристикам

# %% [markdown]
# # Подготовительные операции

# %%
import numpy as np
import pandas as pd
import sys
import re

from sklearn.model_selection import KFold,train_test_split
from sklearn.tree import ExtraTreeRegressor, DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor, ExtraTreesRegressor, BaggingRegressor, VotingRegressor

from tqdm.notebook import tqdm

from catboost import CatBoostRegressor

import klib

import automl_alex
from automl_alex import AutoMLRegressor, BestSingleModelRegressor

from pandas_profiling import ProfileReport

pd.set_option('max_columns', None)

# %%
def mape(y_true, y_pred):
    return round(np.mean(np.abs((y_pred - y_true) / y_true)*100), 3)

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # Подгружаем данные

# %%
train = pd.read_csv('input/autoru-parsed-0603-1304/new_data_99_06_03_13_04.csv')
test = pd.read_csv('input/sf-dst-car-price/test.csv')
sample_submission = pd.read_csv('input/sf-dst-car-price/sample_submission.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# С помощью пакета Pandas Profiling легко осуществляем EDA анализ датасета и получаем все нужные нам характеристики в одном месте.

# %%
#profile = ProfileReport(train, title="Pandas Profiling Report")

# %%
#profile.to_notebook_iframe()

# %%
#profile.to_file("your_report.html")

# %% [markdown]
# # Data Preprocessing

# %%
train = train.loc[(train.brand == "BMW")]

# %%
klib.data_cleaning(train)
# Out:
# Shape of cleaned data: (14390, 20)Remaining NAs: 9438
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 2
#      of which 2 single valued.     Columns: ['brand', 'таможня']
# Dropped missing values: 0
# Reduced memory by at least: 0.79 MB (-32.51%)
#         unnamed_0          body_type   color fuel_type  model_date  \
# 4760         4760      Хэтчбек 5 дв.  040001    бензин      2007.0
# 4761         4761      Хэтчбек 5 дв.  040001    бензин      2007.0
# 4762         4762      Хэтчбек 5 дв.  FAFBFB    бензин      2017.0
# 4763         4763      Хэтчбек 5 дв.  EE1D19    бензин      2011.0
# 4764         4764      Хэтчбек 5 дв.  FAFBFB    бензин      2011.0
# ...           ...                ...     ...       ...         ...
# 108321     108321  Внедорожник 5 дв.  0000CC    бензин      2012.0
# 108322     108322  Внедорожник 5 дв.  040001    дизель      2014.0
# 108323     108323  Внедорожник 5 дв.  040001    дизель      2014.0
# 108324     108324  Внедорожник 5 дв.  FAFBFB    бензин      2009.0
# 108325     108325  Внедорожник 5 дв.  0000CC    бензин      2014.0
#
#                                name  number_of_doors  production_date  \
# 4760         116i 1.6 AT (115 л.с.)              5.0             2008
# 4761         116i 1.6 AT (115 л.с.)              5.0             2011
# 4762         118i 1.5 AT (136 л.с.)              5.0             2017
# 4763         116i 1.6 AT (136 л.с.)              5.0             2014
# 4764         116i 1.6 AT (136 л.с.)              5.0             2013
# ...                             ...              ...              ...
# 108321    35i 3.0 AT (306 л.с.) 4WD              5.0             2013
# 108322  M50d 3.0d AT (381 л.с.) 4WD              5.0             2016
# 108323   30d 3.0d AT (249 л.с.) 4WD              5.0             2016
# 108324        4.4 AT (555 л.с.) 4WD              5.0             2011
# 108325        4.4 AT (575 л.с.) 4WD              5.0             2015
#
#        vehicle_configuration engine_displacement  engine_power  \
# 4760               AUTOMATIC                116i         115.0
# 4761               AUTOMATIC                116i         115.0
# 4762               AUTOMATIC                118i         136.0
# 4763               AUTOMATIC                116i         136.0
# 4764               AUTOMATIC                116i         136.0
# ...                      ...                 ...           ...
# 108321             AUTOMATIC                 35i         306.0
# 108322             AUTOMATIC                M50d         381.0
# 108323             AUTOMATIC                 30d         249.0
# 108324             AUTOMATIC                 4.4         555.0
# 108325             AUTOMATIC                 4.4         575.0
#
#                                               description  mileage  \
# 4760    Вся в родне в оригинале продаю так как 3 машин...   115000
# 4761    Приобретался новым у официального дилера BMW А...    39728
# 4762    Машина в отличном состоянии. Не курили. Все то...    41000
# 4763    МБ-Беляево — официальный дилер «Мерседес-Бенц»...    87284
# 4764    Машина в хорошем состоянии покупал у знакомых,...   124000
# ...                                                   ...      ...
# 108321  Автомобиль представлен официальным дилером BMW...    76670
# 108322  Максимальная комплектация
# По любым вопросам зв...   101000
# 108323                                               <NA>   108000
# 108324  КОМПЛЕКТАЦИЯ: INDIVIDUAL
# Я первый и единственн...   143400
# 108325  Комплектация самая полная и дорогая Individual...    45000
#
#                                              комплектация  привод  руль  \
# 4760                                          {'id': '0'}  задний  LEFT
# 4761    {'id': '2430196', 'name': '116', 'available_op...  задний  LEFT
# 4762                                          {'id': '0'}  задний  LEFT
# 4763    {'id': '7707468', 'name': '116i', 'available_o...  задний  LEFT
# 4764    {'id': '7707468', 'name': '116i', 'available_o...  задний  LEFT
# ...                                                   ...     ...   ...
# 108321                                        {'id': '0'}  полный  LEFT
# 108322                                        {'id': '0'}  полный  LEFT
# 108323  {'id': '21075602', 'name': 'xDrive30d', 'avail...  полный  LEFT
# 108324  {'id': '4731958', 'name': 'X6 M', 'available_o...  полный  LEFT
# 108325                                        {'id': '0'}  полный  LEFT
#
#         владельцы       птс                     владение    price
# 4760          2.0  ORIGINAL                          NaN   436000
# 4761          1.0  ORIGINAL   {'year': 2011, 'month': 4}   595000
# 4762          2.0  ORIGINAL                          NaN  1150000
# 4763          3.0  ORIGINAL                          NaN   660000
# 4764          3.0  ORIGINAL                          NaN   575000
# ...           ...       ...                          ...      ...
# 108321        3.0  ORIGINAL                          NaN  1795000
# 108322        1.0  ORIGINAL   {'year': 2016, 'month': 8}  3580000
# 108323        1.0  ORIGINAL   {'year': 2016, 'month': 6}  2600000
# 108324        1.0  ORIGINAL   {'year': 2011, 'month': 9}  1450000
# 108325        1.0  ORIGINAL  {'year': 2015, 'month': 12}  3499000
#
# [14390 rows x 20 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14390 entries, 4760 to 108325
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            14390 non-null  int64
#  1   bodyType              14390 non-null  object
#  2   brand                 14390 non-null  object
#  3   color                 14390 non-null  object
#  4   fuelType              14390 non-null  object
#  5   modelDate             14390 non-null  float64
#  6   name                  14390 non-null  object
#  7   numberOfDoors         14390 non-null  float64
#  8   productionDate        14390 non-null  int64
#  9   vehicleConfiguration  14390 non-null  object
#  10  engineDisplacement    14390 non-null  object
#  11  enginePower           14390 non-null  float64
#  12  description           14081 non-null  object
#  13  mileage               14390 non-null  int64
#  14  Комплектация          14390 non-null  object
#  15  Привод                14390 non-null  object
#  16  Руль                  14390 non-null  object
#  17  Владельцы             14388 non-null  float64
#  18  ПТС                   14390 non-null  object
#  19  Таможня               14390 non-null  bool
#  20  Владение              5263 non-null   object
#  21  Price                 14390 non-null  int64
# dtypes: bool(1), float64(4), int64(4), object(13)
# memory usage: 2.4+ MB

# %%
train.sample(3)
# Out:
#        Unnamed: 0           bodyType brand   color fuelType  modelDate  \
# 85528       85528  Внедорожник 5 дв.   BMW  040001   дизель     2014.0
# 79728       79728               Купе   BMW  040001   бензин     2005.0
# 8512         8512               Купе   BMW  FAFBFB   бензин     2011.0
#
#                                     name  numberOfDoors  productionDate  \
# 85528         30d 3.0d AT (249 л.с.) 4WD            5.0            2017
# 79728        325xi 2.5 AT (218 л.с.) 4WD            2.0            2007
# 8512   640i xDrive 3.0 AT (320 л.с.) 4WD            2.0            2013
#
#       vehicleConfiguration engineDisplacement  enginePower  \
# 85528            AUTOMATIC                30d        249.0
# 79728            AUTOMATIC              325xi        218.0
# 8512             AUTOMATIC               640i        320.0
#
#                                              description  mileage  \
# 85528  Куплена в 2018 году в мае \nВ идеальном состоя...    49000
# 79728  автомобиль в отличном техническом состоянии, е...   152000
# 8512   РОЛЬФ Премиум – крупнейший официальный дилер М...    94874
#
#                                             Комплектация  Привод  Руль  \
# 85528  {'id': '21041261', 'name': 'xDrive30d', 'avail...  полный  LEFT
# 79728  {'id': '4721835', 'name': '325', 'available_op...  полный  LEFT
# 8512                                         {'id': '0'}  полный  LEFT
#
#        Владельцы       ПТС  Таможня                    Владение    Price
# 85528        1.0  ORIGINAL     True  {'year': 2018, 'month': 5}  2820000
# 79728        3.0  ORIGINAL     True                         NaN   640000
# 8512         2.0  ORIGINAL     True                         NaN  1795000

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3837 entries, 0 to 3836
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bodyType              3837 non-null   object
#  1   brand                 3837 non-null   object
#  2   color                 3837 non-null   object
#  3   fuelType              3837 non-null   object
#  4   modelDate             3837 non-null   float64
#  5   name                  3837 non-null   object
#  6   numberOfDoors         3837 non-null   float64
#  7   productionDate        3837 non-null   float64
#  8   vehicleConfiguration  3837 non-null   object
#  9   vehicleTransmission   3837 non-null   object
#  10  engineDisplacement    3837 non-null   object
#  11  enginePower           3837 non-null   object
#  12  description           3837 non-null   object
#  13  mileage               3837 non-null   float64
#  14  Комплектация          3837 non-null   object
#  15  Привод                3837 non-null   object
#  16  Руль                  3837 non-null   object
#  17  Состояние             3837 non-null   object
#  18  Владельцы             3837 non-null   object
#  19  ПТС                   3837 non-null   object
#  20  Таможня               3837 non-null   object
#  21  Владение              1753 non-null   object
#  22  id                    3837 non-null   int64
# dtypes: float64(4), int64(1), object(18)
# memory usage: 689.6+ KB

# %%
test.sample(3)
# Out:
#              bodyType brand        color fuelType  modelDate  \
# 1315  универсал 5 дв.   BMW  серебристый   дизель     2005.0
# 2269            седан   BMW        белый   дизель     2013.0
# 2325             купе   BMW        синий   бензин     2013.0
#
#                                      name  numberOfDoors  productionDate  \
# 1315              320d 2.0d AT (177 л.с.)            5.0          2007.0
# 2269  M550d xDrive 3.0d AT (381 л.с.) 4WD            4.0          2013.0
# 2325    420i xDrive 2.0 AT (184 л.с.) 4WD            2.0          2016.0
#
#              vehicleConfiguration vehicleTransmission engineDisplacement  \
# 1315  WAGON_5_DOORS AUTOMATIC 2.0      автоматическая            2.0 LTR
# 2269          SEDAN AUTOMATIC 3.0      автоматическая            3.0 LTR
# 2325          COUPE AUTOMATIC 2.0      автоматическая            2.0 LTR
#
#      enginePower                                        description   mileage  \
# 1315     177 N12  Причина продажи — покупка автомобиля выше клас...  267000.0
# 2269     381 N12   Есть цезарь + Webasto Машина в отличном состо...  149000.0
# 2325     184 N12  ДТП - нет!\n1. На паковочном месте зацепили за...   54000.0
#
#                                            Комплектация  Привод   Руль  \
# 1315  ['[{"name":"Прочее","values":["Защита картера"...  задний  Левый
# 2269  ['[{"name":"Комфорт","values":["Круиз-контроль...  полный  Левый
# 2325  ['[{"name":"Комфорт","values":["Круиз-контроль...  полный  Левый
#
#                Состояние    Владельцы       ПТС     Таможня  \
# 1315  Не требует ремонта  3 или более  Оригинал  Растаможен
# 2269  Не требует ремонта  3 или более  Оригинал  Растаможен
# 2325  Не требует ремонта   1 владелец  Оригинал  Растаможен
#
#                  Владение    id
# 1315  3 года и 11 месяцев  1315
# 2269           10 месяцев  2269
# 2325    2 года и 2 месяца  2325

# %%
# Для корректного объединения датасетов переименуем vehicleConfiguration в vehicleTransmission в train
train.rename(columns={'vehicleConfiguration': 'vehicleTransmission'}, inplace=True)

# Для корректной обработки признаков объединяем трейн и тест в один датасет
train['sample'] = 1 # помечаем где у нас трейн
test['sample'] = 0 # помечаем где у нас тест
test['Price'] = 0 # в тесте у нас нет значения price, мы его должны предсказать, поэтому пока просто заполняем нулями

data = test.append(train, sort=False).reset_index(drop=True) # объединяем

# %%
data.sample(5)
# Out:
#                 bodyType brand   color fuelType  modelDate  \
# 9880   Внедорожник 5 дв.   BMW  040001   бензин     2010.0
# 14493              Седан   BMW  0000CC   бензин     2001.0
# 10827  Внедорожник 5 дв.   BMW  040001   бензин     2012.0
# 12506  Внедорожник 5 дв.   BMW  040001   дизель     2014.0
# 12950  Внедорожник 5 дв.   BMW  200204   бензин     2012.0
#
#                              name  numberOfDoors  productionDate  \
# 9880    35i 3.0 AT (306 л.с.) 4WD            5.0          2010.0
# 14493      320i 2.2 AT (170 л.с.)            4.0          2002.0
# 10827   35i 3.0 AT (306 л.с.) 4WD            5.0          2013.0
# 12506  20d 2.0d AT (190 л.с.) 4WD            5.0          2017.0
# 12950       18i 2.0 AT (150 л.с.)            5.0          2014.0
#
#       vehicleConfiguration vehicleTransmission engineDisplacement enginePower  \
# 9880                   NaN           AUTOMATIC                35i         306
# 14493                  NaN           AUTOMATIC               320i         170
# 10827                  NaN           AUTOMATIC                35i         306
# 12506                  NaN           AUTOMATIC                20d         190
# 12950                  NaN           AUTOMATIC                18i         150
#
#                                              description   mileage  \
# 9880   Автомобиль куплен в Балт Авто Трейд-М 21.01.20...  162800.0
# 14493  Продаётся отличный «Бумер», в достойном состоя...  280000.0
# 10827  Внимание! Данный автомобиль Вы можете приобрес...   66654.0
# 12506  Комплектация MSport. Состояние нового автомоби...   70000.0
# 12950                                                NaN   70158.0
#
#                                             Комплектация  Привод  Руль  \
# 9880                                         {'id': '0'}  полный  LEFT
# 14493                                        {'id': '0'}  задний  LEFT
# 10827  {'id': '8494869', 'name': 'xDrive35i', 'availa...  полный  LEFT
# 12506  {'id': '21073109', 'name': 'xDrive20d M Sport ...  полный  LEFT
# 12950  {'id': '6937724', 'name': 'sDrive18i Локальная...  задний  LEFT
#
#       Состояние Владельцы       ПТС Таможня                    Владение  id  \
# 9880        NaN         3  ORIGINAL    True  {'year': 2011, 'month': 2} NaN
# 14493       NaN         3  ORIGINAL    True                         NaN NaN
# 10827       NaN         2  ORIGINAL    True                         NaN NaN
# 12506       NaN         1  ORIGINAL    True                         NaN NaN
# 12950       NaN         1  ORIGINAL    True                         NaN NaN
#
#        sample    Price  Unnamed: 0
# 9880        1  1000000     10803.0
# 14493       1   359999     79698.0
# 10827       1  1559000     11750.0
# 12506       1  1950000     63850.0
# 12950       1   921000     67270.0

# %%
#
data.drop(columns=['name', 'vehicleConfiguration', 'engineDisplacement', 'description', 'Комплектация', 'Руль', 'Состояние', 'id', 'Unnamed: 0'], inplace=True,)

# Обработаем признак "Владение"
data['bodyType'] = data['bodyType'].apply(lambda x: str(x))
def bodyType(row):
    for body_type in ['внедорожник', 'хэтчбек', 'купе-хардтоп', 'седан', 'универсал', 
                      'родстер', 'кабриолет', 'компактвэн', 'лифтбек', 'купе']:
        if row.lower().startswith(body_type):
            return body_type
data['bodyType'] = data['bodyType'].apply(bodyType)
data['bodyType'] = data['bodyType'].apply(lambda x: 'купе' if x == 'купе-хардтоп' else x)

# Обработаем признак "color"
data['color'] = data['color'].map({'CACECB': 'серебристый', 'FAFBFB':'белый', 'EE1D19':'красный', '97948F':'серый', 
                                     '660099':'пурпурный', '040001':'чёрный','4A2197':'фиолетовый', 
                                     '200204':'коричневый','0000CC':'синий', '007F00':'зелёный', 'C49648':'бежевый',
                                     '22A0F8':'голубой','DEA522':'золотистый','FFD600': 'жёлтый', 'FF8649':'оранжевый',
                                     'FFC0CB':'розовый'})

# Обработаем признак "vehicleTransmission"
data['vehicleTransmission'] = data['vehicleTransmission'].map({'AUTOMATIC': 'автоматическая', 'MECHANICAL': 'механическая', 'ROBOT': 'роботизированная',})

# Обработаем признак "enginePower"
data['enginePower'] = data['enginePower'].apply(lambda x: x if isinstance(x, float) else int(str(x).split()[0]))

# Обработаем признак "Владельцы"
data['Владельцы'] = data['Владельцы'].apply(lambda x: x if isinstance(x, float) else int(str(x).split()[0]))

# Обработаем признак "ПТС"
data['ПТС'] = data['ПТС'].map({'ORIGINAL': 'Оригинал', 'DUPLICATE': 'Дубликат'})

# Mеняем названия колонок
data.columns = ['bodyType', 'color', 'fuelType', 'modelDate', 'numberOfDoors',
                'productionDate', 'vehicleTransmission', 'enginePower', 'mileage',
                'drive', 'numOwn', 'docs', 'durOwn', 'sample', 'Price']

# Удалаяем необработанные признаки
data.drop(['durOwn',], axis=1, inplace=True,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-98cde2a22b5d> in <module>
#      32
#      33 # Mеняем названия колонок
# ---> 34 data.columns = ['bodyType', 'color', 'fuelType', 'modelDate', 'numberOfDoors',
#      35                 'productionDate', 'vehicleTransmission', 'enginePower', 'mileage',
#      36                 'drive', 'numOwn', 'docs', 'durOwn', 'sample', 'Price']
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 17 elements, new values have 15 elements

# %%
data.sample(5)
# Out:
#           bodyType        color fuelType  modelDate  numberOfDoors  \
# 7493         седан       чёрный   бензин     1987.0            4.0
# 13553      хэтчбек        белый   бензин     2007.0            5.0
# 9789   внедорожник  серебристый   дизель     2013.0            5.0
# 6624         седан       чёрный   дизель     2013.0            4.0
# 347    внедорожник          NaN   дизель     2010.0            5.0
#
#        productionDate vehicleTransmission  enginePower   mileage   drive  \
# 7493           1990.0        механическая        150.0  250000.0  задний
# 13553          2011.0      автоматическая        136.0  105816.0  задний
# 9789           2017.0      автоматическая        313.0   67600.0  полный
# 6624           2014.0      автоматическая        258.0  115000.0  полный
# 347            2013.0                 NaN        184.0   79094.0  полный
#
#        numOwn      docs  sample    Price
# 7493      3.0  Дубликат       1   215000
# 13553     2.0  Оригинал       1   595000
# 9789      1.0  Оригинал       1  3450000
# 6624      2.0  Оригинал       1  1649000
# 347       1.0       NaN       0        0

# %%
data['numOwn'] = data['numOwn'].fillna(data['numOwn'].value_counts().idxmax())

for column in ['bodyType', 'color', 'fuelType', 'vehicleTransmission', 'drive', 'docs']:
    data[column] = data[column].astype('category').cat.codes  

data = pd.get_dummies(data, columns=['bodyType', 'color', 'fuelType', 'vehicleTransmission', 'drive', 'docs'])

for column in ['modelDate', 'numberOfDoors', 'productionDate', 'enginePower', 'mileage', 'numOwn']:
        data[column] = data[column].astype('int32')

# %%
#profile = ProfileReport(data, title="Pandas Profiling Report")
#profile.to_widgets()

# %%
train_data = data.query('sample == 1').drop(['sample'], axis=1)
test_data = data.query('sample == 0').drop(['sample'], axis=1)
data = train_data

y = train_data['Price'].values
X = train_data.drop(['Price'], axis=1)
X_sub = test_data.drop(['Price'], axis=1)

# %% [markdown]
# # Train Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=RANDOM_SEED)

# %% [markdown]
# # Fit&Submit AutoML

# %% [markdown]
# AutoMLRegressor

# %%
model = AutoMLRegressor(X_train, y_train, X_test, random_state = RANDOM_SEED, verbose = 1)

# %%
predict_test, predict_train = model.fit_predict(timeout = 8000, verbose = 1)

# %%
model.stack_models_cfgs

# %%
print('MAPE train:  ', mape(y_train, predict_train), '%')
print('MAPE test:  ', mape(y_test, predict_test), '%')

# %%
#predict_submission = model.predict(X_sub)
#sample_submission['price'] = predict_submission
#sample_submission['price'] = sample_submission['price'].apply(lambda x: round(x/1000)*1000)
#sample_submission.to_csv(f'automl_ensemble.csv', index=False)

# %% [markdown]
# BestSingleModelRegressor

# %%
model = BestSingleModelRegressor(X_train, y_train, X_test, random_state = RANDOM_SEED, verbose = 1)

# %%
history = model.opt(timeout=8000, verbose=1)

# %%
model.history_trials_dataframe.head(5)

# %%
#model.plot_opt_history()

# %%
predicts = model.predict()
predicts.head(5)

# %%
print('MAPE train:  ', mape(y_train, predicts['predict_train'][0]), '%')
print('MAPE test:  ', mape(y_test, predicts['predict_test'][0]), '%')

# %%
#predict_submission = model.predict(X_sub)
#sample_submission['price'] = predict_submission
#sample_submission['price'] = sample_submission['price'].apply(lambda x: round(x/1000)*1000)
#sample_submission.to_csv(f'automl_single.csv', index=False)

# %% [markdown]
# # Fit&Submit H2O

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ---------------------------------------------------------
# H2O_cluster_uptime:         10 hours 4 mins
# H2O_cluster_timezone:       Europe/Moscow
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.2
# H2O_cluster_version_age:    10 days
# H2O_cluster_name:           H2O_from_python_user_6vhchd
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    5.708 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ---------------------------------------------------------

# %%
df = h2o.H2OFrame(data)
y = 'Price'
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
aml = H2OAutoML(max_runtime_secs = 600, seed = RANDOM_SEED, project_name = "prj")
aml.train(y = y, training_frame = df)
# Out:
# AutoML progress: |█████
# 00:04:24.227: AutoML: XGBoost is not available; skipping it.
# 00:12:24.766: New models will be added to existing leaderboard prj@@Price (leaderboard frame=null) with already 21 models.
# 00:12:24.766: AutoML: XGBoost is not available; skipping it.
# 00:19:56.850: StackedEnsemble_BestOfFamily_AutoML_20201128_001224 [StackedEnsemble best (built using top model from each algorithm type)] failed: water.exceptions.H2OIllegalArgumentException: Failed to find the xval predictions frame. . .  Looks like keep_cross_validation_predictions wasn't set when building the models, or the frame was deleted.
# 00:19:57.857: StackedEnsemble_AllModels_AutoML_20201128_001224 [StackedEnsemble all (built using all AutoML models)] failed: water.exceptions.H2OIllegalArgumentException: Failed to find the xval predictions frame. . .  Looks like keep_cross_validation_predictions wasn't set when building the models, or the frame was deleted.
# 10:09:33.266: New models will be added to existing leaderboard prj@@Price (leaderboard frame=null) with already 47 models.
# 10:09:33.273: AutoML: XGBoost is not available; skipping it.
#
# ██████████████████████████████████████████████
# 10:18:23.445: StackedEnsemble_BestOfFamily_AutoML_20201128_100933 [StackedEnsemble best (built using top model from each algorithm type)] failed: water.exceptions.H2OIllegalArgumentException: Failed to find the xval predictions frame. . .  Looks like keep_cross_validation_predictions wasn't set when building the models, or the frame was deleted.
# 10:18:24.449: StackedEnsemble_AllModels_AutoML_20201128_100933 [StackedEnsemble all (built using all AutoML models)] failed: water.exceptions.H2OIllegalArgumentException: Failed to find the xval predictions frame. . .  Looks like keep_cross_validation_predictions wasn't set when building the models, or the frame was deleted.
#
# █████| 100%

# %%
aml.leaderboard.head()
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">  rmse</th><th style="text-align: right;">        mse</th><th style="text-align: right;">   mae</th><th style="text-align: right;">   rmsle</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20201128_000424   </td><td style="text-align: right;">             8.03942e+10</td><td style="text-align: right;">283539</td><td style="text-align: right;">8.03942e+10</td><td style="text-align: right;">135261</td><td style="text-align: right;">0.192037</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20201128_000424</td><td style="text-align: right;">             8.25544e+10</td><td style="text-align: right;">287323</td><td style="text-align: right;">8.25544e+10</td><td style="text-align: right;">134580</td><td style="text-align: right;">0.193543</td></tr>
# <tr><td>XRT_1_AutoML_20201128_100933                       </td><td style="text-align: right;">             8.46637e+10</td><td style="text-align: right;">290970</td><td style="text-align: right;">8.46637e+10</td><td style="text-align: right;">135443</td><td style="text-align: right;">0.191277</td></tr>
# <tr><td>XRT_1_AutoML_20201128_001224                       </td><td style="text-align: right;">             8.48358e+10</td><td style="text-align: right;">291266</td><td style="text-align: right;">8.48358e+10</td><td style="text-align: right;">135751</td><td style="text-align: right;">0.19125 </td></tr>
# <tr><td>DRF_1_AutoML_20201128_100933                       </td><td style="text-align: right;">             8.70054e+10</td><td style="text-align: right;">294967</td><td style="text-align: right;">8.70054e+10</td><td style="text-align: right;">135846</td><td style="text-align: right;">0.193176</td></tr>
# <tr><td>DRF_1_AutoML_20201128_001224                       </td><td style="text-align: right;">             8.70854e+10</td><td style="text-align: right;">295102</td><td style="text-align: right;">8.70854e+10</td><td style="text-align: right;">136183</td><td style="text-align: right;">0.193249</td></tr>
# <tr><td>XRT_1_AutoML_20201128_000424                       </td><td style="text-align: right;">             8.87462e+10</td><td style="text-align: right;">297903</td><td style="text-align: right;">8.87462e+10</td><td style="text-align: right;">138779</td><td style="text-align: right;">0.194508</td></tr>
# <tr><td>GBM_1_AutoML_20201128_001224                       </td><td style="text-align: right;">             8.93836e+10</td><td style="text-align: right;">298971</td><td style="text-align: right;">8.93836e+10</td><td style="text-align: right;">152898</td><td style="text-align: right;">0.204518</td></tr>
# <tr><td>GBM_1_AutoML_20201128_100933                       </td><td style="text-align: right;">             8.93836e+10</td><td style="text-align: right;">298971</td><td style="text-align: right;">8.93836e+10</td><td style="text-align: right;">152898</td><td style="text-align: right;">0.204518</td></tr>
# <tr><td>GBM_grid__1_AutoML_20201128_000424_model_1         </td><td style="text-align: right;">             8.97651e+10</td><td style="text-align: right;">299608</td><td style="text-align: right;">8.97651e+10</td><td style="text-align: right;">139916</td><td style="text-align: right;">0.205834</td></tr>
# </tbody>
# </table>

# %%
train = h2o.H2OFrame(X_train)
test = h2o.H2OFrame(X_test)
predict_train = aml.predict(train)
predict_test = aml.predict(test)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%

# %%
y__test_pred = predict_test.as_data_frame()
y__test_pred = y__test_pred.apply(lambda x: round(x/1000)*1000)
y__test_pred = y__test_pred.to_numpy()
y__test_pred = y__test_pred.flatten().astype(int)

# %%
y_test
# Out:
# array([2820000,  640000, 1795000, ..., 1225000,   90000, 2490000],
#       dtype=int64)

# %%
y__test_pred
# Out:
# array([3064000,  636000, 1733000, ..., 1292000,  125000, 2455000])

# %%
print('MAPE test:  ', mape(y_test, y__test_pred), '%')
# Out:
# MAPE test:   5.846 %
